# %% [markdown]
# <a href="https://colab.research.google.com/github/theresa042612/API/blob/main/COVID_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Latest Covid-19 Data
# The API returns:
#
# Summary stats (count of cases, recoveries and deaths)
#
# Global
# Mainland China
# Non-Mainland China
# Raw data (counts by region as published in the Google Sheet)
#
# Metadata (including when data was last published and the cache status)

# %%
import requests

# %%
jsonResponse = requests.get('https://coronavirus.m.pipedream.net/')

# %%
jsonResponse.status_code
# Out:
# 200

# %%
jsonResponse.json()
# Out:
# {'apiSourceCode': 'https://pipedream.com/@/p_G6CLVM',
#  'cache': {'expires': 'in 4 minutes',
#   'expiresTimestamp': 1633652078538,
#   'lastUpdated': 'a minute ago',
#   'lastUpdatedTimestamp': 1633651778538},
#  'dataSource': {'lastGithubCommit': '2021-10-07T17:03:01Z',
#   'publishedBy': 'John Hopkins University Center for Systems Science and Engineering',
#   'ref': 'https://github.com/CSSEGISandData/COVID-19',
#   'url': 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/10-06-2021.csv'},
#  'rawData': [{'Active': '',
#    'Admin2': '',
#    'Case_Fatality_Ratio': '4.646672673445746',
#    'Combined_Key': 'Afghanistan',
#    'Confirmed': '155380',
#    'Country_Region': 'Afghanistan',
#    'Deaths': '7220',
#    'FIPS': '',
#    'Incident_Rate': '399.14364704111074',
#    'Last_Update': '2021-10-07 04:21:36',
#    'Lat': '33.93911',
#    'Long_': '67.709953',
#    'Province_State': '',
#    'Recovered': ''},
# ...
